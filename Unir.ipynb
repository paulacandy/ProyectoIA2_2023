# %%
import cv2
import numpy as np
import os
import matplotlib.pyplot as plt
import pandas as pd
import sys
import matplotlib.pyplot as plt
from sklearn import datasets
import tensorflow as tf
from sklearn import utils
from sklearn.model_selection import train_test_split
from keras import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.models import *
from tensorflow.keras.applications import *
from tensorflow.keras.preprocessing import *
from tensorflow.keras.callbacks import EarlyStopping

print(tf.__version__)


from google.colab import drive
drive.mount('/content/drive')


# %cd '/content/drive/MyDrive/IA2_PROYECTOFINAL/Dataset/'
# Out:
# 2.11.0
# Mounted at /content/drive
# /content/drive/MyDrive/IA2_PROYECTOFINAL/Dataset

# %%
x1= np.load("/content/drive/MyDrive/IA2_PROYECTOFINAL/Dataset/1/x1.npy")
x2= np.load("/content/drive/MyDrive/IA2_PROYECTOFINAL/Dataset/2/x2.npy")
x3= np.load("/content/drive/MyDrive/IA2_PROYECTOFINAL/Dataset/3/x3.npy")
x4= np.load("/content/drive/MyDrive/IA2_PROYECTOFINAL/Dataset/4/x4.npy")

# %%
y1= np.load("/content/drive/MyDrive/IA2_PROYECTOFINAL/Dataset/1/y1.npy")
y2= np.load("/content/drive/MyDrive/IA2_PROYECTOFINAL/Dataset/2/y2.npy")
y3= np.load("/content/drive/MyDrive/IA2_PROYECTOFINAL/Dataset/3/y3.npy")
y4= np.load("/content/drive/MyDrive/IA2_PROYECTOFINAL/Dataset/4/y4.npy")

print(np.shape(y1))
# Out:
# (11500,)

# %%
x = np.concatenate([x1, x2,x3,x4])
y = np.concatenate([y1, y2, y3, y4])

count = np.count_nonzero(y == 0)
countt = np.count_nonzero(y == 1)

print('De NR hay ', count, 'y de SR ', countt)
# Out:
# De NR hay  2703 y de SR  26883

# %%
print(len(x))
print(len(y))

#Me aseguro del shape de las x y y
print('x',np.shape(x), ' y sus unique van de: ', np.unique(x))
print('y',np.shape(y), ' y sus unique van de: ', np.unique(y))

# %%
plt.figure(figsize=(7,7))
for i in range(20):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x[i].reshape(32,32,3), cmap=plt.cm.binary)

    #plt.xlabel(class_names[int(Y_test[i,1])])

# %%
y = tf.keras.utils.to_categorical(y)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state=42)

print(np.shape(x_train))
print(np.shape(x_test))
# Out:
# (20710, 32, 32, 3)
# (8876, 32, 32, 3)

# %%
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')


# %cd '/content/drive/MyDrive/IA2_PROYECTOFINAL/Dataset/Binarios'

np.save('x_train',x_train)
np.save('x_test',x_test)
np.save('y_test',y_test)
np.save('y_train',y_train)
# Out:
# /content/drive/MyDrive/IA2_PROYECTOFINAL/Dataset/Binarios
