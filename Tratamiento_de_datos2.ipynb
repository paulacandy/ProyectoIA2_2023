# %%
#Librerías 
import cv2
import numpy as np
import os as os
import matplotlib.pyplot as plt
import pandas as pd
from skimage.transform import resize

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd '/content/drive/MyDrive/IA2_PROYECTOFINAL/Dataset/2'
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/IA2_PROYECTOFINAL/Dataset/2

# %%
#Ya lo descomprimí una vez ya no es necesario
#!unzip LF_dataset.zip
# Out:
# Archive:  LF_dataset.zip
#    creating: LF_dataset/
#    creating: LF_dataset/image/
#    creating: LF_dataset/image/Fabric/
#   inflating: LF_dataset/image/Fabric/001.png
#   inflating: LF_dataset/image/Fabric/002.png
#   inflating: LF_dataset/image/Fabric/003.png
#   inflating: LF_dataset/image/Fabric/004.png
#   inflating: LF_dataset/image/Fabric/005.png
#   inflating: LF_dataset/image/Fabric/006.png
#   inflating: LF_dataset/image/Fabric/007.png
#   inflating: LF_dataset/image/Fabric/008.png
#   inflating: LF_dataset/image/Fabric/009.png
#   inflating: LF_dataset/image/Fabric/010.png
#   inflating: LF_dataset/image/Fabric/011.png
#   inflating: LF_dataset/image/Fabric/012.png
#   inflating: LF_dataset/image/Fabric/013.png
#   inflating: LF_dataset/image/Fabric/014.png
#   inflating: LF_dataset/image/Fabric/015.png
#   inflating: LF_dataset/image/Fabric/016.png
#   inflating: LF_dataset/image/Fabric/017.png
#   inflating: LF_dataset/image/Fabric/018.png
# ...

# %%
#Primero para SIRECICLABLES+

ruta_1 = "/content/drive/MyDrive/IA2_PROYECTOFINAL/Dataset/2/LF_dataset/image/Fabric"

SR = []
im_size=32

for im in os.listdir(ruta_1):
  try:
    im = cv2.imread(os.path.join(ruta_1,im))

    img = cv2.resize(im, (im_size,im_size))
    SR.append(img)
  except: pass
    

ruta_2 = "/content/drive/MyDrive/IA2_PROYECTOFINAL/Dataset/2/LF_dataset/image/Glass"

for im in os.listdir(ruta_2):
  try:
    im = cv2.imread(os.path.join(ruta_2,im))

    img = cv2.resize(im, (im_size,im_size))
    SR.append(img)
  except: pass
    

ruta_3 = "/content/drive/MyDrive/IA2_PROYECTOFINAL/Dataset/2/LF_dataset/image/Leather"

for im in os.listdir(ruta_3):
  try:
    im = cv2.imread(os.path.join(ruta_3,im))

    img = cv2.resize(im, (im_size,im_size))
    SR.append(img)
  except:
    pass

ruta_4 = "/content/drive/MyDrive/IA2_PROYECTOFINAL/Dataset/2/LF_dataset/image/Metal"

for im in os.listdir(ruta_4):
  try:
    im = cv2.imread(os.path.join(ruta_4,im))

    img = cv2.resize(im, (im_size,im_size))
    SR.append(img)
  except:
    pass

ruta_5 = "/content/drive/MyDrive/IA2_PROYECTOFINAL/Dataset/2/LF_dataset/image/Paper"

for im in os.listdir(ruta_5):
  try:
    im = cv2.imread(os.path.join(ruta_5,im))

    img = cv2.resize(im, (im_size,im_size))
    SR.append(img)
  except:
    pass

ruta_6 = "/content/drive/MyDrive/IA2_PROYECTOFINAL/Dataset/2/LF_dataset/image/Plastic"

for im in os.listdir(ruta_6):
  try:
    im = cv2.imread(os.path.join(ruta_6,im))

    img = cv2.resize(im, (im_size,im_size))
    SR.append(img)
  except:
    pass

ruta_7 = "/content/drive/MyDrive/IA2_PROYECTOFINAL/Dataset/2/LF_dataset/image/Wood"

for im in os.listdir(ruta_7):
  try:
    im = cv2.imread(os.path.join(ruta_7,im))

    img = cv2.resize(im, (im_size,im_size))
    SR.append(img)
  except:
    pass


len(SR)
# Out:
# 700

# %%
#Ahora NO RECICLABLES

ruta_27 = "/content/drive/MyDrive/IA2_PROYECTOFINAL/Dataset/2/LF_dataset/image/Foliage"

NR = []
im_size=32

for im in os.listdir(ruta_27):
  try:
    im = cv2.imread(os.path.join(ruta_27,im))

    img = cv2.resize(im, (im_size,im_size))
    NR.append(img)
  except: pass


ruta_28 = "/content/drive/MyDrive/IA2_PROYECTOFINAL/Dataset/2/LF_dataset/image/Fur"

for im in os.listdir(ruta_28):
  try:
    im = cv2.imread(os.path.join(ruta_28,im))

    img = cv2.resize(im, (im_size,im_size))
    NR.append(img)
  except:
    pass

ruta_29 = "/content/drive/MyDrive/IA2_PROYECTOFINAL/Dataset/2/LF_dataset/image/Stone"

for im in os.listdir(ruta_29):
  try:
    im = cv2.imread(os.path.join(ruta_29,im))

    img = cv2.resize(im, (im_size,im_size))
    NR.append(img)
  except:
    pass

# %%
len(NR)
# Out:
# 300

# %%
x1=SR
y1=np.repeat(1, len(SR))
x2=NR
y2=np.repeat(0, len(NR))

# %%
type(x1)
# Out:
# list

# %%
#pasamos de list a np
x1=np.array(x1)
x2=np.array(x2)

# %%
#Primero con np.unique supe que sus valores venian de 0-255
#np.unique(x1)
#como vienen de 0-255 entonces:
x1=x1/255
x2=x2/255
#y las concateno
x=np.concatenate((x1,x2))
y=np.concatenate((y1,y2))
#acá averiguo de qué tamaño viene la imagen
print(np.shape(x))
# Out:
# (1000, 32, 32, 3)

# %%
np.save('x2',x)
np.save('y2',y)

# %%
print(np.shape(x),np.shape(y))
# Out:
# (1000, 32, 32, 3) (1000,)
