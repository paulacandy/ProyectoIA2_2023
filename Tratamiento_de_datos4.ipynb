# %%
##Librerías 
import cv2
import numpy as np
import os as os
import matplotlib.pyplot as plt
import pandas as pd
from skimage.transform import resize

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd '/content/drive/MyDrive/IA2_PROYECTOFINAL/Dataset/4/imagesfromgit'
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/IA2_PROYECTOFINAL/Dataset/4/imagesfromgit

# %%
#No se repite porque ya cloné una vez
#!git clone https://github.com/nikhilvenkatkumsetty/TrashBox.git
# Out:
# Cloning into 'TrashBox'...
# remote: Enumerating objects: 17962, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 17962 (delta 12), reused 0 (delta 0), pack-reused 17941
# Receiving objects: 100% (17962/17962), 2.66 GiB | 16.73 MiB/s, done.
# Resolving deltas: 100% (161/161), done.
# Updating files: 100% (28564/28564), done.

# %%
#Primero para SIRECICLABLES+

ruta_1 = "/content/drive/MyDrive/IA2_PROYECTOFINAL/Dataset/4/imagesfromgit/TrashBox/TrashBox_train_dataset_subfolders/cardboard/"

SR = []
im_size=32

for im in os.listdir(ruta_1):
  try:
    im = cv2.imread(os.path.join(ruta_1,im))

    img = cv2.resize(im, (im_size,im_size))
    SR.append(img)
  except: pass
    

ruta_2 = "/content/drive/MyDrive/IA2_PROYECTOFINAL/Dataset/4/imagesfromgit/TrashBox/TrashBox_train_dataset_subfolders/e-waste/electrical cables"

for im in os.listdir(ruta_2):
  try:
    im = cv2.imread(os.path.join(ruta_2,im))

    img = cv2.resize(im, (im_size,im_size))
    SR.append(img)
  except: pass
    

ruta_3 = "/content/drive/MyDrive/IA2_PROYECTOFINAL/Dataset/4/imagesfromgit/TrashBox/TrashBox_train_dataset_subfolders/e-waste/electronic chips"

for im in os.listdir(ruta_3):
  try:
    im = cv2.imread(os.path.join(ruta_3,im))

    img = cv2.resize(im, (im_size,im_size))
    SR.append(img)
  except:
    pass

ruta_4 = "/content/drive/MyDrive/IA2_PROYECTOFINAL/Dataset/4/imagesfromgit/TrashBox/TrashBox_train_dataset_subfolders/e-waste/laptops"

for im in os.listdir(ruta_4):
  try:
    im = cv2.imread(os.path.join(ruta_4,im))

    img = cv2.resize(im, (im_size,im_size))
    SR.append(img)
  except:
    pass

ruta_5 = "/content/drive/MyDrive/IA2_PROYECTOFINAL/Dataset/4/imagesfromgit/TrashBox/TrashBox_train_dataset_subfolders/e-waste/small appliances"

for im in os.listdir(ruta_5):
  try:
    im = cv2.imread(os.path.join(ruta_5,im))

    img = cv2.resize(im, (im_size,im_size))
    SR.append(img)
  except:
    pass

ruta_6 = "/content/drive/MyDrive/IA2_PROYECTOFINAL/Dataset/4/imagesfromgit/TrashBox/TrashBox_train_dataset_subfolders/e-waste/smartphones"

for im in os.listdir(ruta_6):
  try:
    im = cv2.imread(os.path.join(ruta_6,im))

    img = cv2.resize(im, (im_size,im_size))
    SR.append(img)
  except:
    pass

ruta_7 = "/content/drive/MyDrive/IA2_PROYECTOFINAL/Dataset/4/imagesfromgit/TrashBox/TrashBox_train_dataset_subfolders/glass"

for im in os.listdir(ruta_7):
  try:
    im = cv2.imread(os.path.join(ruta_7,im))

    img = cv2.resize(im, (im_size,im_size))
    SR.append(img)
  except:
    pass

ruta_8 = "/content/drive/MyDrive/IA2_PROYECTOFINAL/Dataset/4/imagesfromgit/TrashBox/TrashBox_train_dataset_subfolders/glass"

for im in os.listdir(ruta_8):
  try:
    im = cv2.imread(os.path.join(ruta_8,im))

    img = cv2.resize(im, (im_size,im_size))
    SR.append(img)
  except:
    pass


ruta_12 = "/content/drive/MyDrive/IA2_PROYECTOFINAL/Dataset/4/imagesfromgit/TrashBox/TrashBox_train_dataset_subfolders/metal/beverage cans"

for im in os.listdir(ruta_12):
  try:
    im = cv2.imread(os.path.join(ruta_12,im))

    img = cv2.resize(im, (im_size,im_size))
    SR.append(img)
  except:
    pass


ruta_13 = "/content/drive/MyDrive/IA2_PROYECTOFINAL/Dataset/4/imagesfromgit/TrashBox/TrashBox_train_dataset_subfolders/metal/construction scrap"

for im in os.listdir(ruta_13):
  try:
    im = cv2.imread(os.path.join(ruta_13,im))

    img = cv2.resize(im, (im_size,im_size))
    SR.append(img)
  except:
    pass


ruta_14 = "/content/drive/MyDrive/IA2_PROYECTOFINAL/Dataset/4/imagesfromgit/TrashBox/TrashBox_train_dataset_subfolders/metal/metal containers"

for im in os.listdir(ruta_14):
  try:
    im = cv2.imread(os.path.join(ruta_14,im))

    img = cv2.resize(im, (im_size,im_size))
    SR.append(img)
  except:
    pass


ruta_15 = "/content/drive/MyDrive/IA2_PROYECTOFINAL/Dataset/4/imagesfromgit/TrashBox/TrashBox_train_dataset_subfolders/metal/other metal objects"

for im in os.listdir(ruta_15):
  try:
    im = cv2.imread(os.path.join(ruta_15,im))

    img = cv2.resize(im, (im_size,im_size))
    SR.append(img)
  except:
    pass

ruta_16 = "/content/drive/MyDrive/IA2_PROYECTOFINAL/Dataset/4/imagesfromgit/TrashBox/TrashBox_train_dataset_subfolders/metal/spray cans"

for im in os.listdir(ruta_16):
  try:
    im = cv2.imread(os.path.join(ruta_16,im))

    img = cv2.resize(im, (im_size,im_size))
    SR.append(img)
  except:
    pass


ruta_17= "/content/drive/MyDrive/IA2_PROYECTOFINAL/Dataset/4/imagesfromgit/TrashBox/TrashBox_train_dataset_subfolders/paper/news paper"

for im in os.listdir(ruta_17):
  try:
    im = cv2.imread(os.path.join(ruta_17,im))

    img = cv2.resize(im, (im_size,im_size))
    SR.append(img)
  except:
    pass


ruta_18 = "/content/drive/MyDrive/IA2_PROYECTOFINAL/Dataset/4/imagesfromgit/TrashBox/TrashBox_train_dataset_subfolders/paper/paper cups"

for im in os.listdir(ruta_18):
  try:
    im = cv2.imread(os.path.join(ruta_18,im))

    img = cv2.resize(im, (im_size,im_size))
    SR.append(img)
  except:
    pass


ruta_19 = "/content/drive/MyDrive/IA2_PROYECTOFINAL/Dataset/4/imagesfromgit/TrashBox/TrashBox_train_dataset_subfolders/paper/paper"

for im in os.listdir(ruta_19):
  try:
    im = cv2.imread(os.path.join(ruta_19,im))

    img = cv2.resize(im, (im_size,im_size))
    SR.append(img)
  except:
    pass


ruta_20 = "/content/drive/MyDrive/IA2_PROYECTOFINAL/Dataset/4/imagesfromgit/TrashBox/TrashBox_train_dataset_subfolders/paper/tetra pak"

for im in os.listdir(ruta_20):
  try:
    im = cv2.imread(os.path.join(ruta_20,im))

    img = cv2.resize(im, (im_size,im_size))
    SR.append(img)
  except:
    pass



ruta_21 = "/content/drive/MyDrive/IA2_PROYECTOFINAL/Dataset/4/imagesfromgit/TrashBox/TrashBox_train_dataset_subfolders/plastic/plastic bags"

for im in os.listdir(ruta_21):
  try:
    im = cv2.imread(os.path.join(ruta_21,im))

    img = cv2.resize(im, (im_size,im_size))
    SR.append(img)
  except:
    pass


ruta_22 = "/content/drive/MyDrive/IA2_PROYECTOFINAL/Dataset/4/imagesfromgit/TrashBox/TrashBox_train_dataset_subfolders/plastic/plastic bags"

for im in os.listdir(ruta_22):
  try:
    im = cv2.imread(os.path.join(ruta_22,im))

    img = cv2.resize(im, (im_size,im_size))
    SR.append(img)
  except:
    pass


ruta_23 = "/content/drive/MyDrive/IA2_PROYECTOFINAL/Dataset/4/imagesfromgit/TrashBox/TrashBox_train_dataset_subfolders/plastic/plastic bottles"

for im in os.listdir(ruta_23):
  try:
    im = cv2.imread(os.path.join(ruta_23,im))

    img = cv2.resize(im, (im_size,im_size))
    SR.append(img)
  except:
    pass


ruta_24 = "/content/drive/MyDrive/IA2_PROYECTOFINAL/Dataset/4/imagesfromgit/TrashBox/TrashBox_train_dataset_subfolders/plastic/plastic bottles"

for im in os.listdir(ruta_24):
  try:
    im = cv2.imread(os.path.join(ruta_24,im))

    img = cv2.resize(im, (im_size,im_size))
    SR.append(img)
  except:
    pass

ruta_25 = "/content/drive/MyDrive/IA2_PROYECTOFINAL/Dataset/4/imagesfromgit/TrashBox/TrashBox_train_dataset_subfolders/plastic/plastic containers"

for im in os.listdir(ruta_25):
  try:
    im = cv2.imread(os.path.join(ruta_25,im))

    img = cv2.resize(im, (im_size,im_size))
    SR.append(img)
  except:
    pass

ruta_26 = "/content/drive/MyDrive/IA2_PROYECTOFINAL/Dataset/4/imagesfromgit/TrashBox/TrashBox_train_dataset_subfolders/plastic/plastic cups"

for im in os.listdir(ruta_26):
  try:
    im = cv2.imread(os.path.join(ruta_26,im))

    img = cv2.resize(im, (im_size,im_size))
    SR.append(img)
  except:
    pass

# %%
#Ahora NO RECICLABLES

ruta_27 = "/content/drive/MyDrive/IA2_PROYECTOFINAL/Dataset/4/imagesfromgit/TrashBox/TrashBox_train_dataset_subfolders/medical/gloves"

NR = []
im_size=32

for im in os.listdir(ruta_27):
  try:
    im = cv2.imread(os.path.join(ruta_27,im))

    img = cv2.resize(im, (im_size,im_size))
    NR.append(img)
  except: pass


ruta_28 = "/content/drive/MyDrive/IA2_PROYECTOFINAL/Dataset/4/imagesfromgit/TrashBox/TrashBox_train_dataset_subfolders/medical/masks"

for im in os.listdir(ruta_28):
  try:
    im = cv2.imread(os.path.join(ruta_28,im))

    img = cv2.resize(im, (im_size,im_size))
    NR.append(img)
  except:
    pass


ruta_29 = "/content/drive/MyDrive/IA2_PROYECTOFINAL/Dataset/4/imagesfromgit/TrashBox/TrashBox_train_dataset_subfolders/medical/medicines"

for im in os.listdir(ruta_29):
  try:
    im = cv2.imread(os.path.join(ruta_29,im))

    img = cv2.resize(im, (im_size,im_size))
    NR.append(img)
  except:
    pass

ruta_30 = "/content/drive/MyDrive/IA2_PROYECTOFINAL/Dataset/4/imagesfromgit/TrashBox/TrashBox_train_dataset_subfolders/medical/syringe"

for im in os.listdir(ruta_30):
  try:
    im = cv2.imread(os.path.join(ruta_30,im))

    img = cv2.resize(im, (im_size,im_size))
    NR.append(img)
  except:
    pass

len(NR)
# Out:
# 1563

# %%
#Reviso los SR qué longitud tienen
print(len(SR))
#los paso a np
x1=np.array(SR)
#print(np.unique(x1)) como segun esto tiene de 0-255 entonces:
x1=x1/255
print(np.shape(x1))
#Saco la 'y' para estos 'x'
y1=np.repeat(1,np.shape(x1)[0])
print(np.unique(y1))
# Out:
# 14683
# (14683, 32, 32, 3)
# [1]

# %%
#Reviso los NR qué longitud tienen
print(len(NR))
#los paso a np
x2=np.array(NR)
#print(np.unique(x2)) #como segun esto tiene de 0-255 entonces:
x2=x2/255
print(np.shape(x2))
#Saco la 'y' para estos 'x'
y2=np.repeat(0,np.shape(x2)[0])
#print(np.unique(x2))
# Out:
# 1563
# (1563, 32, 32, 3)

# %%
#concateno ambos
x=np.concatenate((x1,x2))
y=np.concatenate((y1,y2))

# %%
# %cd '/content/drive/MyDrive/IA2_PROYECTOFINAL/Dataset/4'

np.save('x4',x)
np.save('y4',y)
# Out:
# /content/drive/MyDrive/IA2_PROYECTOFINAL/Dataset/4

# %%
print(np.shape(x),np.shape(y))
# Out:
# (16246, 32, 32, 3) (16246,)
